# %% [markdown]
# <a href="https://colab.research.google.com/github/super30-pro/Data-Analytics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/ML_ALL_benchmarks.csv')

# %%
data
# Out:
#                                   device   company            cpuName  cores  \
# 0                      iPhone 13 Pro Max     Apple      A15 Bionic         6
# 1                          iPhone 13 Pro     Apple      A15 Bionic         6
# 2                         iPhone 13 mini     Apple      A15 Bionic         6
# 3    iPad Pro (12.9-inch 5th generation)     Apple             M1          8
# 4      iPad Pro (11-inch 3rd generation)     Apple             M1          8
# ..                                   ...       ...                ...    ...
# 183               Samsung Galaxy Note FE   Samsung     Exynos 8890         8
# 184                      Huawei Nexus 6P  Qualcomm  Snapdragon 810         8
# 185                          LG Nexus 5X  Qualcomm  Snapdragon 808         6
# 186                               LG V30  Qualcomm  Snapdragon 835         8
# 187                  Samsung Galaxy A21s   Samsung      Exynos 850         8
#
#      clock  cpuScore  gpuScore  npuScore
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   device    188 non-null    object
#  1   company   188 non-null    object
#  2   cpuName   188 non-null    object
#  3   cores     188 non-null    int64
#  4   clock     188 non-null    int64
#  5   cpuScore  188 non-null    int64
#  6   gpuScore  188 non-null    int64
#  7   npuScore  188 non-null    int64
# dtypes: int64(5), object(3)
# memory usage: 11.9+ KB

# %%
data.describe()
# Out:
#             cores        clock     cpuScore     gpuScore     npuScore
# count  188.000000   188.000000   188.000000   188.000000   188.000000
# mean     7.303191  1966.430851   342.361702   932.728723   651.962766
# std      1.494586   386.177373   201.452658   525.293486   628.687083
# min      2.000000  1300.000000    78.000000    75.000000    56.000000
# 25%      8.000000  1785.000000   208.500000   519.750000   271.750000
# 50%      8.000000  1804.000000   312.500000   840.000000   413.000000
# 75%      8.000000  2000.000000   392.250000  1265.500000   755.000000
# max      8.000000  3230.000000  1013.000000  2842.000000  2676.000000

# %%
data.isnull()
# Out:
#      device  company  cpuName  cores  clock  cpuScore  gpuScore  npuScore
# 0     False    False    False  False  False     False     False     False
# 1     False    False    False  False  False     False     False     False
# 2     False    False    False  False  False     False     False     False
# 3     False    False    False  False  False     False     False     False
# 4     False    False    False  False  False     False     False     False
# ..      ...      ...      ...    ...    ...       ...       ...       ...
# 183   False    False    False  False  False     False     False     False
# 184   False    False    False  False  False     False     False     False
# 185   False    False    False  False  False     False     False     False
# 186   False    False    False  False  False     False     False     False
# 187   False    False    False  False  False     False     False     False
#
# [188 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# device      0
# company     0
# cpuName     0
# cores       0
# clock       0
# cpuScore    0
# gpuScore    0
# npuScore    0
# dtype: int64

# %%
company_counts = data['company'].value_counts()
print(company_counts)
# Out:
# company
# Qualcomm     106
# Apple         44
# Samsung       16
# HiSilicon     10
# MediaTek       9
# Google         2
# NVIDIA         1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Re-defining the data
companies = ["Qualcomm", "Apple", "Samsung", "HiSilicon", "MediaTek", "Google", "NVIDIA"]
values = [106, 44, 16, 10, 9, 2, 1]

# Calculate the cumulative sum for the waterfall effect
cumulative_values = np.cumsum(values)

# Set colors for waterfall (positive and negative)
colors = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1', '#D65076', '#45B8AC']

# Start plot
plt.style.use('dark_background')
fig1, ax = plt.subplots(figsize=(10, 6))
fig1.set_facecolor("black")

# Create the bars for the waterfall chart
ax.bar(companies, values, color=colors)

# Add a line showing cumulative values
ax.plot(companies, cumulative_values, color='white', marker='o', linestyle='--', linewidth=2)

# Set chart title and labels
plt.title("Waterfall Chart for Phone Companies by Market Usage", color="white", fontsize=14)
plt.xlabel("Companies", color="white", fontsize=12)
plt.ylabel("Values", color="white", fontsize=12)

# Customize ticks for better visibility
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')

# Display the chart using fig1.show()
plt.tight_layout()
fig1.show()

# %%
cpu_counts = data['cpuName'].value_counts()
print(cpu_counts)
# Out:
# cpuName
# Snapdragon 845        13
# Snapdragon 855        13
# Snapdragon 865        13
# Snapdragon 835        10
# Snapdragon 888        10
#                       ..
# Kirin 9000             1
# Snapdragon 780G        1
# Snapdragon 750G        1
# Snapdragon 730G        1
# Exynos 850             1
# Name: count, Length: 63, dtype: int64

# %%
# Data for CPU usage
cpu_names = [
    "Snapdragon 845", "Snapdragon 855", "Snapdragon 865",
    "Snapdragon 835", "Snapdragon 888", "Kirin 9000",
    "Snapdragon 780G", "Snapdragon 750G", "Snapdragon 730G", "Exynos 850"
]
cpu_values = [13, 13, 13, 10, 10, 1, 1, 1, 1, 1]

# Visualization with a black background
plt.style.use('dark_background')

fig2, ax = plt.subplots()
fig2.set_facecolor("black")
colors = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1', '#D65076', '#45B8AC', '#EFC050', '#5B5EA6', '#9B2335']

# Create the horizontal bar chart
ax.barh(cpu_names, cpu_values, color=colors)
ax.invert_yaxis()  # Highest value at the top

# Customizing the chart
ax.tick_params(axis='x', colors='white')
ax.tick_params(axis='y', colors='white')
plt.title("Most Popular Chipsets in Smartphones", color="white", fontsize=14)
plt.xlabel("Usage Count", color="white", fontsize=12)

# Display the graph using fig2.show()
plt.tight_layout()
fig2.show()

# %%
core_counts = data['cores'].value_counts()
print(core_counts)
# Out:
# cores
# 8    146
# 6     26
# 4      8
# 2      7
# 3      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# Data for cores and their counts
cores = [8, 6, 4, 2, 3]
counts = [146, 26, 8, 7, 1]

# Plot with black background
plt.style.use('dark_background')

fig3, ax = plt.subplots()
fig3.set_facecolor("black")

# Create a donut chart (pie chart with a hole)
colors = ['#FF6F61', '#6B5B95', '#88B04B', '#F7CAC9', '#92A8D1']
wedges, texts = ax.pie(
    counts,
    labels=[f"{core} Cores" for core in cores],
    startangle=140,
    colors=colors,
    textprops={'color': "white"},
    wedgeprops=dict(width=0.4)
)

# Add a circle at the center to create the "donut" effect
centre_circle = plt.Circle((0, 0), 0.70, fc='black')  # Center circle matches the background
fig3.gca().add_artist(centre_circle)

# Customizing the chart for better visibility
plt.title("Cores Used in Smartphones", color="white", fontsize=16)

# Display the chart using fig3.show()
plt.tight_layout()
fig3.show()

# %%
# Extract top 6 devices by CPU score
top_cpu_scores = data.nlargest(6, 'cpuScore')[['device', 'cpuScore']]

# Display the data
print(top_cpu_scores)
# Out:
#                                 device  cpuScore
# 3  iPad Pro (12.9-inch 5th generation)      1013
# 4    iPad Pro (11-inch 3rd generation)      1011
# 0                    iPhone 13 Pro Max       935
# 1                        iPhone 13 Pro       931
# 2                       iPhone 13 mini       924
# 5                            iPhone 13       916

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Data for the devices and their respective CPU scores
devices = ['iPad Pro (12.9-inch 5th generation)', 'iPad Pro (11-inch 3rd generation)', 'iPhone 13 Pro Max',
           'iPhone 13 Pro', 'iPhone 13 mini', 'iPhone 13']
cpu_scores = [1013, 1011, 935, 931, 924, 916]

# Create a color palette for the bars
colors = list(mcolors.TABLEAU_COLORS.values())  # Use Tableau colors for diversity

# Vertical Bar Chart
fig4, ax = plt.subplots(figsize=(10, 6))
ax.bar(devices, cpu_scores, color=colors)
ax.set_ylabel('CPU Score', fontsize=14, color='white')
ax.set_xlabel('Device Name', fontsize=14, color='white')
ax.set_title('Top Devices by CPU Score', fontsize=16, color='white')
ax.set_facecolor('black')  # Set background to black
plt.xticks(rotation=45, ha='right', color='white')  # Rotate x-axis labels for better readability
plt.yticks(color='white')  # Set y-axis ticks color to white
plt.tight_layout()

# Display the chart using fig4.show()
fig4.show()

# %%
# Extract top 6 devices by GPU score
top_gpu_scores = data.nlargest(6, 'gpuScore')[['device', 'gpuScore']]

# Display the data
print(top_gpu_scores)
# Out:
#                                 device  gpuScore
# 4    iPad Pro (11-inch 3rd generation)      2842
# 3  iPad Pro (12.9-inch 5th generation)      2824
# 0                    iPhone 13 Pro Max      2273
# 1                        iPhone 13 Pro      2261
# 6           iPad mini (6th generation)      2095
# 7            iPad Air (4th generation)      1950

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Data for the devices and their respective GPU scores
devices = ['iPad Pro (11-inch 3rd generation)', 'iPad Pro (12.9-inch 5th generation)', 'iPhone 13 Pro Max',
           'iPhone 13 Pro', 'iPad mini (6th generation)', 'iPad Air (4th generation)']
gpu_scores = [2842, 2824, 2273, 2261, 2095, 1950]

# Create a color palette for the bars
colors = list(mcolors.TABLEAU_COLORS.values())  # Use Tableau colors for diversity

# Line Graph
fig5, ax = plt.subplots(figsize=(10, 6))
ax.plot(devices, gpu_scores, marker='o', color='cyan', linestyle='-', linewidth=2, markersize=8)
ax.set_xlabel('Device Name', fontsize=14, color='white')
ax.set_ylabel('GPU Score', fontsize=14, color='white')
ax.set_title('Top GPU Scores Trend Across Devices', fontsize=16, color='white')
plt.xticks(rotation=45, ha='right', color='white')  # Rotate x-axis labels for better readability
plt.yticks(color='white')  # Set y-axis ticks color to white
ax.set_facecolor('black')  # Set background to black
plt.tight_layout()

# Display the chart using fig5.show()
fig5.show()

# %%
# Extract top 6 devices by NPU score
top_npu_scores = data.nlargest(6, 'npuScore')[['device', 'npuScore']]

# Display the data
print(top_npu_scores)
# Out:
#                                 device  npuScore
# 0                    iPhone 13 Pro Max      2676
# 1                        iPhone 13 Pro      2665
# 2                       iPhone 13 mini      2660
# 3  iPad Pro (12.9-inch 5th generation)      2657
# 4    iPad Pro (11-inch 3rd generation)      2656
# 5                            iPhone 13      2605

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the devices and their respective NPU scores
devices = ['iPhone 13 Pro Max', 'iPhone 13 Pro', 'iPhone 13 mini',
           'iPad Pro (12.9-inch 5th generation)', 'iPad Pro (11-inch 3rd generation)', 'iPhone 13']
npu_scores = [2676, 2665, 2660, 2657, 2656, 2605]

# Sort the NPU scores and corresponding devices in descending order
sorted_indices = np.argsort(npu_scores)[::-1]
sorted_devices = np.array(devices)[sorted_indices]
sorted_npu_scores = np.array(npu_scores)[sorted_indices]

# Calculate the cumulative sum of NPU scores and the cumulative percentage
cumulative_scores = np.cumsum(sorted_npu_scores)
total_score = cumulative_scores[-1]
cumulative_percentage = cumulative_scores / total_score * 100

# Create a figure and axis
fig6, ax1 = plt.subplots(figsize=(10, 6))

# Plot the bar chart
ax1.bar(sorted_devices, sorted_npu_scores, color='skyblue')
ax1.set_xlabel('Device Name', fontsize=14, color='white')
ax1.set_ylabel('NPU Score', fontsize=14, color='white')
ax1.set_title('Top NPU Scores by Device', fontsize=16, color='white')
ax1.tick_params(axis='x', rotation=45, labelcolor='white')  # Rotate x-axis labels for better readability
ax1.tick_params(axis='y', labelcolor='white')
ax1.set_facecolor('black')  # Set background to black

# Create a second y-axis to plot the cumulative percentage line
ax2 = ax1.twinx()
ax2.plot(sorted_devices, cumulative_percentage, color='red', marker='o', linestyle='-', linewidth=2)
ax2.set_ylabel('Cumulative Percentage (%)', fontsize=14, color='white')
ax2.tick_params(axis='y', labelcolor='white')

# Set the background to black for the second axis as well
ax2.set_facecolor('black')

# Show the chart using fig6.show()
plt.tight_layout()
fig6.show()

# %%
import pandas as pd

# Example data (assuming you already have this in a DataFrame 'data')
data = pd.DataFrame({
    'device': ['iPhone 13 Pro Max', 'iPhone 13 Pro', 'iPhone 13 mini', 'iPad Pro (12.9-inch 5th generation)',
               'iPad Pro (11-inch 3rd generation)', 'iPhone 13', 'iPad mini (6th generation)', 'iPad Air (4th generation)'],
    'npuScore': [2676, 2665, 2660, 2657, 2656, 2605, 0, 0],  # Example NPU scores
    'gpuScore': [2273, 2261, 2240, 2824, 2842, 2220, 2095, 1950]  # Example GPU scores
})

# Extract top 6 devices by NPU score
top_npu_scores = data.nlargest(6, 'npuScore')[['device', 'npuScore']]

# Extract top 6 devices by GPU score
top_gpu_scores = data.nlargest(6, 'gpuScore')[['device', 'gpuScore']]

# Find common devices
common_devices = pd.merge(top_npu_scores, top_gpu_scores, on='device')

# Display common devices and their scores
print("\nCommon Devices and their NPU and GPU Scores:")
print(common_devices[['device', 'npuScore', 'gpuScore']])
# Out:
# Common Devices and their NPU and GPU Scores:
#                                 device  npuScore  gpuScore
# 0                    iPhone 13 Pro Max      2676      2273
# 1                        iPhone 13 Pro      2665      2261
# 2                       iPhone 13 mini      2660      2240
# 3  iPad Pro (12.9-inch 5th generation)      2657      2824
# 4    iPad Pro (11-inch 3rd generation)      2656      2842
# 5                            iPhone 13      2605      2220

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the devices, NPU and GPU scores
devices = ['iPhone 13 Pro Max', 'iPhone 13 Pro', 'iPhone 13 mini',
           'iPad Pro (12.9-inch 5th generation)', 'iPad Pro (11-inch 3rd generation)', 'iPhone 13']
npu_scores = [2676, 2665, 2660, 2657, 2656, 2605]
gpu_scores = [2273, 2261, 2240, 2824, 2842, 2220]

# Create a figure and axis
fig7, ax = plt.subplots(figsize=(10, 6))

# Plotting the stacked bar chart
ax.bar(devices, npu_scores, color='skyblue', label='NPU Score', edgecolor='black')
ax.bar(devices, gpu_scores, bottom=npu_scores, color='orange', label='GPU Score', edgecolor='black')

# Labeling the chart
ax.set_xlabel('Device', fontsize=14, color='white')
ax.set_ylabel('Scores', fontsize=14, color='white')
ax.set_title('NPU and GPU Scores by Device', fontsize=16, color='white')

# Set background color to black and axis labels to white
ax.set_facecolor('black')
ax.tick_params(axis='x', colors='white')  # Change x-axis tick color to white
ax.tick_params(axis='y', colors='white')  # Change y-axis tick color to white

# Add a legend to differentiate the bars and position it outside the plot area
ax.legend(loc='upper left', fontsize=12, bbox_to_anchor=(1.05, 1), borderaxespad=0.)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', color='white')

# Tight layout for better spacing
plt.tight_layout()

# Show the plot using fig7.show()
fig7.show()

# %%
import pandas as pd

# Data for the devices, CPU scores, and Clock speeds (assuming these are in GHz for clock speed)
devices = ['iPhone 13 Pro Max', 'iPhone 13 Pro', 'iPhone 13 mini',
           'iPad Pro (12.9-inch 5th generation)', 'iPad Pro (11-inch 3rd generation)', 'iPhone 13']
cpu_scores = [2676, 2665, 2660, 2657, 2656, 2605]
clock_speeds = [3.23, 3.23, 3.10, 3.20, 3.20, 2.65]  # Example clock speeds in GHz

# Creating a DataFrame for better display
data = pd.DataFrame({
    'Device': devices,
    'CPU Score': cpu_scores,
    'Clock Speed (GHz)': clock_speeds,
  # Convert GHz to MHz for display
})

# Print the DataFrame in a nice tabular format
print(data.to_string(index=False))
# Out:
#                              Device  CPU Score  Clock Speed (GHz)
#                   iPhone 13 Pro Max       2676               3.23
#                       iPhone 13 Pro       2665               3.23
#                      iPhone 13 mini       2660               3.10
# iPad Pro (12.9-inch 5th generation)       2657               3.20
#   iPad Pro (11-inch 3rd generation)       2656               3.20
#                           iPhone 13       2605               2.65

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the devices, CPU scores, and Clock speeds (in GHz for clock speed)
devices = ['iPhone 13 Pro Max', 'iPhone 13 Pro', 'iPhone 13 mini',
           'iPad Pro (12.9-inch 5th generation)', 'iPad Pro (11-inch 3rd generation)', 'iPhone 13']
cpu_scores = [2676, 2665, 2660, 2657, 2656, 2605]
clock_speeds = [3.23, 3.23, 3.10, 3.20, 3.20, 2.65]  # Clock speeds in GHz

# Convert device names to a numpy array for consistent plotting
device_indices = np.arange(len(devices))

# Create a figure and axis
fig8, ax = plt.subplots(figsize=(10, 6))

# Plot the data points for CPU Scores and Clock Speeds
ax.scatter(device_indices, cpu_scores, color='skyblue', label='CPU Score', s=100, edgecolor='black', zorder=5)
ax.scatter(device_indices, np.array(clock_speeds) * 1000, color='orange', label='Clock Speed (MHz)', s=100, edgecolor='black', zorder=5)

# Labeling the chart
ax.set_xlabel('Device', fontsize=14, color='white')
ax.set_ylabel('Scores / Clock Speed (in MHz)', fontsize=14, color='white')
ax.set_title('Comparison of CPU Scores and Clock Speeds by Device', fontsize=16, color='white')

# Set x-axis labels and make them more readable
ax.set_xticks(device_indices)
ax.set_xticklabels(devices, rotation=45, ha='right', color='white')

# Set background color to black and axis labels to white
ax.set_facecolor('black')
ax.tick_params(axis='x', colors='white')  # Change x-axis tick color to white
ax.tick_params(axis='y', colors='white')  # Change y-axis tick color to white

# Add a legend and position it outside the graph
ax.legend(loc='upper left', fontsize=12, bbox_to_anchor=(1.05, 1), borderaxespad=0.)

# Tight layout for better spacing
plt.tight_layout()

# Show the plot using fig8.show()
fig8.show()

# %%
pip install dash
# Out:
#   File "<ipython-input-30-f4332f20ef45>", line 1
#     pip install dash
#         ^
# SyntaxError: invalid syntax

# %%
pip install dash.ly --upgrade

# %%
import dash
from dash import html   # to code html components
from dash import dcc
import plotly.graph_objects as go
import plotly.express as px
from dash.dependencies import Input, Output
from plotly.subplots import make_subplots

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)  # Fixed typo here

colors = {
    'background': '#111111',
    'text': '#7FDBFF'
}

app.layout = html.Div(style={'backgroundColor': colors['background']}, children=[
    html.H1(
        children='Social Media Usage Analysis',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),
    html.Div(
        children='  - By ',
        style={
            'textAlign': 'center',
            'color': colors['text']
        }
    ),
    dcc.Graph(id='firstgraph1', figure=fig1, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    dcc.Graph(id='firstgraph2', figure=fig2, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph3', figure=fig3, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph4', figure=fig4, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph5', figure=fig5, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph6', figure=fig6, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph7', figure=fig7, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph8', figure=fig8, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph9', figure=fig9, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # dcc.Graph(id='firstgraph10', figure=fig10, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # # dcc.Graph(id='firstgraph11', figure=fig11, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
    # # dcc.Graph(id='firstgraph12', figure=fig12, style={'width': '80%', 'display': 'inline-block', 'backgroundColor': colors['background']}),
])

# Corrected if statement for app execution
if __name__ == '__main__':  # Fixed typo here
    app.run_server()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-29-8840f4c35abd> in <cell line: 1>()
# ----> 1 import dash
#       2 from dash import html   # to code html components
#       3 from dash import dcc
#       4 import plotly.graph_objects as go
#       5 import plotly.express as px
#
# /usr/local/lib/python3.10/dist-packages/dash/__init__.py in <module>
# ----> 1 from .dash import Dash
#       2 from . import development
#       3 from .version import __version__
#
# /usr/local/lib/python3.10/dist-packages/dash/dash.py in <module>
#      13 import collections
#      14
# ---> 15 import dash_renderer
#      16
#      17 from .dependencies import Event, Input, Output, State
#
# ModuleNotFoundError: No module named 'dash_renderer'
#
# ---------------------------------------------------------------------------
# ...
